# %% [markdown]
# <a href="https://colab.research.google.com/github/razaqfatiu/data-visualization/blob/main/Lab4_correlationB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The data in this dataset has no obvious index column (recall that an index column usually has a unique identifier in each row). So first read the data in and check it is in the right format – there should be 5 columns (4 for the measurements and 1 for the variety) and 150 rows. [Hint: don't include the parameter index_col=0 when you read it in.]

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('https://tinyurl.com/ChrisCoDV/iris.csv')
data.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %% [markdown]
#  Create a single visualisation showing scatter subplots for all pairs of measurements. You may find the following line of code useful:
# selected = ['sepal.length', 'sepal.width', 'petal.length', 'petal.width'] Comment on the strongest correlation, visually.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

data = pd.read_csv('https://tinyurl.com/ChrisCoDV/iris.csv')

selected = ['sepal.length', 'sepal.width', 'petal.length', 'petal.width']

pd.plotting.register_matplotlib_converters()

counter = 1
fig = plt.figure(figsize=(12, 12))
fig.suptitle('Flower size correlation', fontsize=14, position=(0.5, 1.0))
for i, name_i in enumerate(selected):
    for j in range(i + 1, len(selected)):
        name_j = selected[j]
        sub = fig.add_subplot(4, 4, counter)
        sub.set_title(name_i + ' vs ' + name_j, fontsize=10)
        sub.scatter(data[name_i], data[name_j], s=0.5)
        counter += 1
plt.subplots_adjust(wspace=0.5, hspace=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# 2nd, and 6th seems to have more correlation, however there is a margin btw

# %% [markdown]
# Now confirm your findings by creating a heatmap showing the correlations between all the measurements. Which 3 pairs of measurements are most strongly correlated?

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns


data = pd.read_csv('https://tinyurl.com/ChrisCoDV/iris.csv')

pd.plotting.register_matplotlib_converters()
print(data.head())

selected = ['sepal.length', 'sepal.width', 'petal.length', 'petal.width']

plt.figure(figsize=(10, 10))
corr = data[selected].corr()
ax = sns.heatmap(corr, vmin=-1, vmax=1, center=0, cmap=sns.diverging_palette(220, 20, n=200), square=True, annot=True,
                 annot_kws={"size": 8})
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
plt.show()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %% [markdown]
# sepal.length, petal length and petal width are the 3 pairs with strong correlation

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns


data = pd.read_csv('https://tinyurl.com/ChrisCoDV/iris.csv')

pd.plotting.register_matplotlib_converters()

# selected = ['sepal.length', 'sepal.width', 'petal.length', 'petal.width']


data = data[data['variety'] == 'Setosa']
# print(data_setosa.head())


pd.plotting.register_matplotlib_converters()

counter = 1
fig = plt.figure(figsize=(12, 12))
fig.suptitle('Flower size correlation', fontsize=14, position=(0.5, 1.0))
for i, name_i in enumerate(selected):
    for j in range(i + 1, len(selected)):
        name_j = selected[j]
        sub = fig.add_subplot(4, 4, counter)
        sub.set_title(name_i + ' vs ' + name_j, fontsize=10)
        sub.scatter(data[name_i], data[name_j], s=0.5)
        counter += 1
plt.subplots_adjust(wspace=0.5, hspace=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# A heatmap gives a more precise measure than scatter subplots, so create a heatmap showing the correlations between all pairs of measurements for Setosa irises. Comment on the strongest positive correlation. Is there any evidence of inverse correlations?

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns


data = pd.read_csv('https://tinyurl.com/ChrisCoDV/iris.csv')

pd.plotting.register_matplotlib_converters()
# print(data.head())

# selected = ['sepal.length', 'sepal.width', 'petal.length', 'petal.width']

data = data[data['variety'] == 'Setosa']

plt.figure(figsize=(10, 10))
corr = data[selected].corr()
ax = sns.heatmap(corr, vmin=-1, vmax=1, center=0, cmap=sns.diverging_palette(220, 20, n=200), square=True, annot=True,
                 annot_kws={"size": 8})
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
plt.show()

# %% [markdown]
# Repeat item 5 for Versicolor irises and then for Virginica irises.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns


data = pd.read_csv('https://tinyurl.com/ChrisCoDV/iris.csv')

pd.plotting.register_matplotlib_converters()
# print(data.head())

# selected = ['sepal.length', 'sepal.width', 'petal.length', 'petal.width']

data = data[data['variety'] == 'Versicolor']

plt.figure(figsize=(10, 10))
corr = data[selected].corr()
ax = sns.heatmap(corr, vmin=-1, vmax=1, center=0, cmap=sns.diverging_palette(220, 20, n=200), square=True, annot=True,
                 annot_kws={"size": 8})
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns


data = pd.read_csv('https://tinyurl.com/ChrisCoDV/iris.csv')

pd.plotting.register_matplotlib_converters()
# print(data.head())

# selected = ['sepal.length', 'sepal.width', 'petal.length', 'petal.width']

data = data[data['variety'] == 'Virginica']

plt.figure(figsize=(10, 10))
corr = data[selected].corr()
ax = sns.heatmap(corr, vmin=-1, vmax=1, center=0, cmap=sns.diverging_palette(220, 20, n=200), square=True, annot=True,
                 annot_kws={"size": 8})
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
plt.show()

# %% [markdown]
# Clearly different varieties of iris have different measurement correlations. It would be nice to summarise this in one single visualisation with different colours for each variety. To achieve this, repeat your code from item 2. However, this time rather than using sub.scatter() to visualise the whole dataset for each pair of measurements, use it repeatedly to visualise each variety. [Hint: replace the line of code containing sub.scatter() with 3 lines, each containing sub.scatter(), but each visualising a different variety].

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

data = pd.read_csv('https://tinyurl.com/ChrisCoDV/iris.csv')

selected = ['sepal.length', 'sepal.width', 'petal.length', 'petal.width']

pd.plotting.register_matplotlib_converters()

counter = 1
fig = plt.figure(figsize=(12, 12))
fig.suptitle('Flower size correlation', fontsize=14, position=(0.5, 1.0))
for i, name_i in enumerate(selected):
    for j in range(i + 1, len(selected)):
      # print(i, data[data['variety'] == 'Virginica'], j)
        name_j = selected[j]
        sub = fig.add_subplot(4, 4, counter)
        sub.set_title(name_i + ' vs ' + name_j, fontsize=10)
        sub.scatter(data[data['variety'] == 'Setosa'][name_i], data[data['variety'] == 'Setosa'][name_j], s=0.5)
        sub.scatter(data[data['variety'] == 'Versicolor'][name_i], data[data['variety'] == 'Versicolor'][name_j], s=0.5)
        sub.scatter(data[data['variety'] == 'Virginica'][name_i], data[data['variety'] == 'Virginica'][name_j], s=0.5)
        # sub.scatter(data[name_i], data[name_j], s=0.5)
        counter += 1
plt.subplots_adjust(wspace=0.5, hspace=0.5)
plt.tight_layout()
plt.show()
